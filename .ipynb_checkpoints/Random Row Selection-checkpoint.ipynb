# %%
import pandas as pd

# %%
profesionalData = pd.read_excel(r'DataSets/Ensayos_profesional.xlsx')
prepaData = pd.read_excel(r'DataSets/Ensayos_preparatoria.xlsx')

# %%
profesionalData.head()
# Out:
#    X1     ARROBA        N00    TERM  \
# 0   1  @00304069  N00701788  201813
# 1   2  @00342436  N00706987  201813
# 2   4  @00432922  N00356003  201813
# 3   6  @00438757  N00620304  201813
# 4  16  @00529263  N00679933  201813
#
#                                          EXPERIENCIA  \
# 0  Hace dos años tuve la oportunidad de viajar y ...
# 1  Primeramente le mando un saludo a usted que va...
# 2  Cursando el tercer semestre de preparatoria, f...
# 3  Como influyo el futbol en el desarrollo de mis...
# 4  Una de las mejores experiencias de apoyo a la ...
#
#                                                METAS P1  \
# 0  Escogí la carrera de ingeniería en desarrollo ...  b
# 1  Mis metas más grandes son hacer descubrimiento...  c
# 2  Mi meta profesional es estudiar la carrera de ...  a
# 3  Me gustaría ser el mejor de mi profesión siemp...  b
# 4  Los valores con los que me identifico del Tecn...  a
#
# ...

# %%
prepaData.head()
# Out:
#    X1     ARROBA        N00    TERM  \
# 0   3  @00432790  N00588935  201813
# 1   5  @00433380  N00643733  201813
# 2   7  @00454816  N00595017  201813
# 3   8  @00513771  N00610122  201813
# 4   9  @00513773  N00599574  201813
#
#                                          EXPERIENCIA  \
# 0  Hace unos años tuve la oportunidad ide ir a la...
# 1  Una de las experiencias mas importantes para m...
# 2  Una experiencia muy importante e influyente en...
# 3  Cuando tenía 10 años acompañe a mi mamá a Sala...
# 4  Lo que ha hecho que sea la persona que soy hoy...
#
#                                                METAS P1  \
# 0  Desde que era niño me interesaba comprender el...  b
# 1  Yo tengo como meta ser una profesionista y par...  c
# 2  Las dos mayores metas en mi vida son: ser un l...  b
# 3  Mis metas son terminar la escuela, seguir con ...  a
# 4  Mis metas para el futuro son:Poder ir a Nueva ...  c
#
# ...

# %%
randomProfesional500 = profesionalData.sample(n=1000)

randomPrepa500 = prepaData.sample(n=1000)

# %%
randomProfesional500
# Out:
#          X1     ARROBA        N00    TERM  \
# 3369   9234  @03182697  N00625707  201813
# 5062  12901  @03212570  N00688494  201813
# 3609   9793  @03187083  N00653797  201813
# 4795  12450  @03206959  N00683413  201813
# 2369   6493  @03168097  N00622964  201813
# 5111  12961  @03213518  N00688498  201813
# 5245  13119  @03216304  N00685255  201813
# 394     635  @02501028  N00197298  201813
# 3445   9444  @03183996  N00625908  201813
# 4055  10799  @03194300  N00637255  201813
# 4187  11112  @03196851  N00662315  201813
# 935    1327  @02806290  N00532826  201813
# 614     862  @02537950  N00255303  201813
# 455     696  @02505696  N00205383  201813
# 1403   3449  @02832591  N00538307  201813
# 747    1024  @02628277  N00390601  201813
# 4926  12725  @03209702  N00657421  201813
# 3007   8232  @03176942  N00604917  201813
# 3699   9997  @03188689  N00643884  201813
# 2406   6571  @03168538  N00626933  201813
# 3995  10667  @03193194  N00652861  201813
# ...

# %%
randomPrepa500
# Out:
#          X1     ARROBA        N00    TERM  \
# 4739   7531  @03173315  N00638045  201813
# 5930   9332  @03183305  N00650971  201813
# 4192   6627  @03168872  N00627819  201813
# 2686   4327  @03108019  N00595332  201813
# 6110   9664  @03185981  N00651602  201813
# 2830   4533  @03157636  N00609917  201813
# 1736   3065  @02830651  N00592897  201813
# 6381  10133  @03189585  N00655831  201813
# 1327   2549  @02827868  N00588549  201813
# 4232   6693  @03169189  N00592172  201813
# 5395   8499  @03178419  N00645489  201813
# 3602   5695  @03163917  N00611237  201813
# 523    1535  @02819210  N00577019  201813
# 5192   8178  @03176682  N00630723  201813
# 3178   5074  @03160541  N00616237  201813
# 4539   7187  @03171399  N00635760  201813
# 5151   8119  @03176382  N00636651  201813
# 1862   3233  @02831666  N00596769  201813
# 4777   7591  @03173675  N00631316  201813
# 2788   4478  @03157431  N00608703  201813
# 3413   5408  @03162521  N00615902  201813
# ...

# %%
randomProfesional500.to_excel(r'C:\Users\emi_l\OneDrive\Documents\TEC DE MONTERREY\8vo semestre\OCJ\JNotebooks\DataSets\ADA_random1000_Profesional.xlsx', index = None, header=True)
randomPrepa500.to_excel(r'C:\Users\emi_l\OneDrive\Documents\TEC DE MONTERREY\8vo semestre\OCJ\JNotebooks\DataSets\ADA_random1000_Preparatoria.xlsx', index = None, header=True)
