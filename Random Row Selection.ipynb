# %% [markdown]
# ## Library and data import

# %%
import pandas as pd

# %%
noAdmssionData = pd.read_excel(r'DataSets/NoAdmitidos.xlsx')

# %%
ensayosProfe = pd.read_excel(r'DataSets/Ensayos_profe_v2.xlsx')
ensayosProfe.head()
# Out:
#    X1     ARROBA        N00    TERM  \
# 0   1  @00304069  N00701788  201813
# 1   2  @00342436  N00706987  201813
# 2   4  @00432922  N00356003  201813
# 3   6  @00438757  N00620304  201813
# 4  16  @00529263  N00679933  201813
#
#                                          EXPERIENCIA  \
# 0  Hace dos años tuve la oportunidad de viajar y ...
# 1  Primeramente le mando un saludo a usted que va...
# 2  Cursando el tercer semestre de preparatoria, f...
# 3  Como influyo el futbol en el desarrollo de mis...
# 4  Una de las mejores experiencias de apoyo a la ...
#
#                                                METAS P1  \
# 0  Escogí la carrera de ingeniería en desarrollo ...  b
# 1  Mis metas más grandes son hacer descubrimiento...  c
# 2  Mi meta profesional es estudiar la carrera de ...  a
# 3  Me gustaría ser el mejor de mi profesión siemp...  b
# 4  Los valores con los que me identifico del Tecn...  a
#
# ...

# %% [markdown]
# ## Random selection of 200 rows

# %%
randomEnsayos = ensayosProfe.sample(n=200)
randomEnsayos
# Out:
#          X1     ARROBA        N00    TERM  \
# 4338  11459  @03199178  N00672771  201813
# 4891  12655  @03208922  N00685496  201813
# 318     559  @02495226  N00577285  201813
# 2357   6467  @03167960  N00596157  201813
# 4246  11252  @03197786  N00177231  201813
# 4990  12814  @03211224  N00685717  201813
# 5593  13516  @03333800  N00702138  201813
# 5115  12966  @03213589  N00684865  201813
# 1573   4140  @03062250  N00605121  201813
# 2368   6492  @03168092  N00561978  201813
# 2099   5714  @03164018  N00600284  201813
# 2759   7457  @03172926  N00633439  201813
# 2675   7263  @03171812  N00623317  201813
# 3789  10214  @03190203  N00660699  201813
# 5723  13658  @03338358  N00578058  201813
# 4670  12195  @03204840  N00680399  201813
# 4656  12169  @03204681  N00613954  201813
# 5        17  @00537504  N00160750  201813
# 1773   4731  @03158653  N00601885  201813
# 3872  10393  @03191544  N00611488  201813
# 2857   7760  @03174496  N00632849  201813
# ...

# %% [markdown]
# ## Data export to excel file

# %%
randomEnsayos.to_excel(r'C:\Users\emi_l\OneDrive\Documents\TEC DE MONTERREY\8vo semestre\OCJ\JNotebooks\DataSets\200_testing.xlsx', index = None, header=True)
