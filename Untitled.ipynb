# %% [markdown]
# ## Clustering con comentarios

# %% [markdown]
# ### Importamos librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %% [markdown]
# ### Mostramos 5 registros del dataset para tener un overview

# %%
commentsDf = pd.read_csv('DataSets/Comentarios.csv', encoding='latin-1')
commentsDf = commentsDf.drop(['ThemesMeta','Summary','EntitiesPerson','EntitiesCompany','EntitiesList','EntitiesPlace','EntitiesProduct'],1)
commentsDf.head()
# Out:
#    ID TIPO          CAMPUS REGION  TAMANO    LATITUD   LONGITUD  ID_PROGRAMA  \
# 0   1  B2C  CSF (Santa Fe)   CDMX  Grande  19.359603 -99.258372         7244
# 1   2  B2C  CSF (Santa Fe)   CDMX  Grande  19.359603 -99.258372         7244
# 2   3  B2C  CSF (Santa Fe)   CDMX  Grande  19.359603 -99.258372         7244
# 3   4  B2C  CSF (Santa Fe)   CDMX  Grande  19.359603 -99.258372         7244
# 4   5  B2C  CSF (Santa Fe)   CDMX  Grande  19.359603 -99.258372         7244
#
#          PROGRAMA ID_EXTERNO_PROGRAMA  ...  FECHA_INICIO_MODULO  \
# 0  Excel Business            csf_1913  ...           28/07/2018
# 1  Excel Business            csf_1913  ...           28/07/2018
# 2  Excel Business            csf_1913  ...           28/07/2018
# 3  Excel Business            csf_1913  ...           28/07/2018
# 4  Excel Business            csf_1913  ...           28/07/2018
#
#   FECHA_FIN_MODULO                                INDICADOR CODIGO_INDICADOR  \
# ...

# %%
commentsDf.groupby('CAMPUS').size().to_frame()
# Out:
#                           0
# CAMPUS
# AGS (Aguascalientes)      3
# CCM (Ciudad de México)  262
# CEM (Estado de México)  181
# CSF (Santa Fe)          376
# GDL (Guadalajara)        69
# HER (Sonora Norte)       10
# LEO (León)               18
# MRL (Morelia)             7
# MTY (Monterrey)          71
# PUE (Puebla)            109
# QRO (Querétaro)         146
# SIN (Sinaloa)            18
# SLP (San Luis Potosí)    38
# TOL (Toluca)             12

# %%
commentsDf[commentsDf.CAMPUS == 'AGS (Aguascalientes)'].campusNum = 1
commentsDf[commentsDf.CAMPUS == 'AGS (Aguascalientes)']
# Out:
#         ID TIPO                CAMPUS REGION   TAMANO    LATITUD    LONGITUD  \
# 1166  1167  B2C  AGS (Aguascalientes)    OCC  Mediano  21.933646 -102.339988
# 1197  1198  B2C  AGS (Aguascalientes)    OCC  Mediano  21.933646 -102.339988
# 1224  1225  B2C  AGS (Aguascalientes)    OCC  Mediano  21.933646 -102.339988
#
#       ID_PROGRAMA                                    PROGRAMA  \
# 1166         5531  Certificación en Lean Six Sigma Black Belt
# 1197         5531  Certificación en Lean Six Sigma Black Belt
# 1224         5531  Certificación en Lean Six Sigma Black Belt
#
#      ID_EXTERNO_PROGRAMA  ...  FECHA_FIN_MODULO  \
# 1166             ags_189  ...        19/05/2018
# 1197             ags_189  ...        10/03/2018
# 1224             ags_189  ...        19/05/2018
#
#                                               INDICADOR CODIGO_INDICADOR  \
# 1166  Retroalimentación para el Instructor y conteni...        CAINST2.0
# ...

# %% [markdown]
# ### Estadística básica de las columnas numéricas

# %%
commentsDf.describe()
# Out:
#                 ID      LATITUD     LONGITUD  ID_PROGRAMA      ID_MODULO  \
# count  1320.000000  1320.000000  1320.000000  1320.000000    1320.000000
# mean    660.500000    20.156885   -99.853487  6547.105303  100936.536364
# std     381.195488     1.786424     1.739253   728.764662   10462.046197
# min       1.000000    19.018729  -110.977318  4796.000000   74817.000000
# 25%     330.750000    19.284895  -100.289794  6446.000000   95419.750000
# 50%     660.500000    19.359603   -99.258372  6734.000000  102848.500000
# 75%     990.250000    20.612602   -99.136141  7059.000000  108017.000000
# max    1320.000000    29.102600   -98.241449  8851.000000  130492.000000
#
#              SCORE
# count  1320.000000
# mean      0.069636
# std       0.220938
# min      -1.000000
# 25%       0.000000
# 50%       0.040000
# 75%       0.200000
# max       1.000000

# %% [markdown]
# ## Dispersión de los datos

# %%
commentsDf.drop(['CAMPUS'],1).hist()
plt.show()

# %% [markdown]
# ### Se define la entrada para el algoritmo, en este caso sólo se utilizarán las columnas op, ex y ag para la variable "x" y categoría para "y"

# %%
x = np.array(commentsDf['SCORE'])
y = np.array(commentsDf['CAMPUS'])
x.shape
# Out:
# (1320,)

# %% [markdown]
# ### Gráfica en 3D con 14 colores representando las categorías

# %%
fig = plt.figure()
ax = Axes3D(fig)
colores=['blue','red','green','blue','cyan','yellow','orange','black','pink','brown','purple','grey','coral','gold']
asignar=[]
for row in y:
    asignar.append(colores[row])
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-9edb09d6f4e9> in <module>
#       4 asignar=[]
#       5 for row in y:
# ----> 6     asignar.append(colores[row])
#       7 ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
#
# TypeError: list indices must be integers or slices, not str
